# %% [markdown]
# # FMO Complex Model Examples

# %% [markdown]
# ### Mean Field calculations

# %%
import numpy as np
import matplotlib.pyplot as plt
from qc_lab import Simulation # import simulation class 
from qc_lab.models import FMOComplex # import model class 
from qc_lab.algorithms import MeanField # import algorithm class 
from qc_lab.dynamics import serial_driver # import dynamics driver

# %%
sim = Simulation()

sim.settings.num_trajs = 200
sim.settings.batch_size = 50
sim.settings.tmax = 30
sim.settings.dt_update = 0.01

sim.model = FMOComplex({
    "kBT": 1,
    "boson_mass": 1,
    "l_reorg": 35 * 0.00509506, # reorganization energy
    "W": 106.14 * 0.00509506, # characteristic frequency
    "A": 200,
})
sim.algorithm = MeanField()

sim.state.wf_db= np.zeros(7, dtype=complex)
sim.state.wf_db[5] += 1.0

data = serial_driver(sim)

t = data.data_dict["t"]
plt.plot(t, np.real(np.einsum("tii->ti",data.data_dict["dm_db"])))
plt.title("Diabatic populations")
plt.show()
# Out:
# 100%|██████████| 3001/3001 [00:18<00:00, 164.15it/s]
# 100%|██████████| 3001/3001 [00:14<00:00, 211.71it/s]
# 100%|██████████| 3001/3001 [00:13<00:00, 215.73it/s]
# 100%|██████████| 3001/3001 [00:14<00:00, 207.30it/s]

# %% [markdown]
# ### Surface Hopping Calculations

# %%
import numpy as np
import matplotlib.pyplot as plt
from qc_lab import Simulation # import simulation class 
from qc_lab.models import FMOComplex # import model class 
from qc_lab.algorithms import FewestSwitchesSurfaceHopping # import algorithm class 
from qc_lab.dynamics import serial_driver # import dynamics driver

# %% [markdown]
# #### Stochastic sampling

# %%
sim = Simulation()

sim.settings.num_trajs = 200
sim.settings.batch_size = 50
sim.settings.tmax = 30
sim.settings.dt_update = 0.01

sim.model = FMOComplex({
    "kBT": 1,
    "boson_mass": 1,
    "l_reorg": 35 * 0.00509506, # reorganization energy
    "W": 106.14 * 0.00509506, # characteristic frequency
    "A": 200,
})
sim.algorithm = FewestSwitchesSurfaceHopping({
    "fssh_deterministic":False,
    "gauge_fixing":'sign_overlap'
})

sim.state.wf_db= np.zeros(7, dtype=complex)
sim.state.wf_db[5] += 1.0

data = serial_driver(sim)

t = data.data_dict["t"]
plt.plot(t, np.real(np.einsum("tii->ti",data.data_dict["dm_db"])))
plt.title("Diabatic populations")
plt.show()
# Out:
# 100%|██████████| 3001/3001 [00:22<00:00, 134.96it/s]
# 100%|██████████| 3001/3001 [00:22<00:00, 133.59it/s]
# 100%|██████████| 3001/3001 [00:23<00:00, 130.30it/s]
# 100%|██████████| 3001/3001 [00:21<00:00, 137.92it/s]

# %% [markdown]
# #### Deterministic sampling
#
# To use deterministic sampling we multiply the number of trajectories and batch size by the number of states. Note that the convergence behavior changes.

# %%
sim = Simulation()

sim.settings.num_trajs = 20*7
sim.settings.batch_size = 5*7
sim.settings.tmax = 30
sim.settings.dt_update = 0.01

sim.model = FMOComplex({
    "kBT": 1,
    "boson_mass": 1,
    "l_reorg": 35 * 0.00509506, # reorganization energy
    "W": 106.14 * 0.00509506, # characteristic frequency
    "A": 200,
})
sim.algorithm = FewestSwitchesSurfaceHopping({
    "fssh_deterministic":True,
    "gauge_fixing":'sign_overlap'
})

sim.state.wf_db= np.zeros(7, dtype=complex)
sim.state.wf_db[5] += 1.0

data = serial_driver(sim)

t = data.data_dict["t"]
plt.plot(t, np.real(np.einsum("tii->ti",data.data_dict["dm_db"])))
plt.title("Diabatic populations")
plt.show()
# Out:
# 100%|██████████| 3001/3001 [00:14<00:00, 208.40it/s]
# 100%|██████████| 3001/3001 [00:15<00:00, 192.80it/s]
# 100%|██████████| 3001/3001 [00:15<00:00, 197.76it/s]
# 100%|██████████| 3001/3001 [00:14<00:00, 203.02it/s]

# %% [markdown]
# ### Using a parllel driver
#
# We will parallelize the above deterministic surface hopping calculation over four tasks.

# %%
from qc_lab.dynamics import parallel_driver_multiprocessing # import dynamics driver

sim = Simulation()

sim.settings.num_trajs = 20*7
sim.settings.batch_size = 5*7
sim.settings.tmax = 30
sim.settings.dt_update = 0.01

sim.model = FMOComplex({
    "kBT": 1,
    "boson_mass": 1,
    "l_reorg": 35 * 0.00509506, # reorganization energy
    "W": 106.14 * 0.00509506, # characteristic frequency
    "A": 200,
})
sim.algorithm = FewestSwitchesSurfaceHopping({
    "fssh_deterministic":True,
    "gauge_fixing":'sign_overlap'
})

sim.state.wf_db= np.zeros(7, dtype=complex)
sim.state.wf_db[5] += 1.0

data = parallel_driver_multiprocessing(sim)

t = data.data_dict["t"]
plt.plot(t, np.real(np.einsum("tii->ti",data.data_dict["dm_db"])))
plt.title("Diabatic populations")
plt.show()
# Out:
# 100%|██████████| 3001/3001 [00:20<00:00, 148.96it/s]
# 100%|██████████| 3001/3001 [00:22<00:00, 136.26it/s]
# 100%|██████████| 3001/3001 [00:22<00:00, 134.60it/s]
# 100%|██████████| 3001/3001 [00:22<00:00, 133.41it/s]
