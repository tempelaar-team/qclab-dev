# %% [markdown]
# # FMO Complex Model Examples

# %% [markdown]
# ### Mean Field calculations

# %%
import numpy as np
import matplotlib.pyplot as plt
from qc_lab import Simulation # import simulation class 
from qc_lab.models import FMOComplex # import model class 
from qc_lab.algorithms import MeanField # import algorithm class 
from qc_lab.dynamics import serial_driver # import dynamics driver

# %%
sim = Simulation()

sim.settings.num_trajs = 200
sim.settings.batch_size = 50
sim.settings.tmax = 30
sim.settings.dt_update = 0.01

sim.model = FMOComplex({
    "kBT": 1,
    "mass": 1,
    "l_reorg": 35 / 208.521, # reorganization energy
    "w_c": 106.14 / 208.521, # characteristic frequency
    "N": 200,
})
sim.algorithm = MeanField()

sim.state.wf_db= np.zeros(7, dtype=complex)
sim.state.wf_db[5] += 1.0

data = serial_driver(sim)

t = data.data_dict["t"]
plt.plot(t, np.real(np.einsum("tii->ti",data.data_dict["dm_db"])))
plt.title("Diabatic populations")
plt.show()
# Out:
# 100%|██████████| 3001/3001 [00:42<00:00, 69.88it/s]
# 100%|██████████| 3001/3001 [00:42<00:00, 70.52it/s]
# 100%|██████████| 3001/3001 [00:39<00:00, 76.66it/s]
# 100%|██████████| 3001/3001 [00:39<00:00, 75.24it/s]

# %% [markdown]
# ### Surface Hopping Calculations

# %%
import numpy as np
import matplotlib.pyplot as plt
from qc_lab import Simulation # import simulation class 
from qc_lab.models import FMOComplex # import model class 
from qc_lab.algorithms import FewestSwitchesSurfaceHopping # import algorithm class 
from qc_lab.dynamics import serial_driver # import dynamics driver

# %% [markdown]
# #### Stochastic sampling

# %%
sim = Simulation()

sim.settings.num_trajs = 200
sim.settings.batch_size = 50
sim.settings.tmax = 30
sim.settings.dt_update = 0.01

sim.model = FMOComplex({
    "kBT": 1,
    "mass": 1,
    "l_reorg": 35 / 208.521, # reorganization energy
    "w_c": 106.14 / 208.521, # characteristic frequency
    "N": 200,
})
sim.algorithm = FewestSwitchesSurfaceHopping({
    "fssh_deterministic":False,
    "gauge_fixing":'sign_overlap'
})

sim.state.wf_db= np.zeros(7, dtype=complex)
sim.state.wf_db[5] += 1.0

data = serial_driver(sim)

t = data.data_dict["t"]
plt.plot(t, np.real(np.einsum("tii->ti",data.data_dict["dm_db"])))
plt.title("Diabatic populations")
plt.show()
# Out:
# 100%|██████████| 3001/3001 [00:49<00:00, 60.63it/s]
# 100%|██████████| 3001/3001 [00:50<00:00, 58.87it/s]
#   2%|▏         | 70/3001 [00:01<01:16, 38.42it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 23
#      20 sim.state.wf_db= np.zeros(7, dtype=complex)
#      21 sim.state.wf_db[5] += 1.0
# ---> 23 data = serial_driver(sim)
#      25 t = data.data_dict["t"]
#      26 plt.plot(t, np.real(np.einsum("tii->ti",data.data_dict["dm_db"])))
#
# File ~/Research/qc_lab-dev/src/qc_lab/dynamics/serial_driver.py:61, in serial_driver(sim, seeds, data)
#      59 new_data = Data(batch_seeds)
#      60 logger.info("Starting dynamics calculation.")
# ---> 61 new_data = dynamics.run_dynamics(sim, parameters, state, new_data)
#      62 logger.info("Dynamics calculation completed.")
#      63 data.add_data(new_data)
#
# File ~/Research/qc_lab-dev/src/qc_lab/dynamics/dynamics.py:34, in run_dynamics(sim, parameter, state, data)
#      32         data.add_output_to_data_dict(sim, state, sim.t_ind)
#      33     # Execute update recipe.
# ---> 34     parameter, state = sim.algorithm.execute_recipe(
#      35         sim, parameter, state, sim.algorithm.update_recipe
#      36     )
#      37 return data
#
# File ~/Research/qc_lab-dev/src/qc_lab/algorithm.py:42, in Algorithm.execute_recipe(self, sim, parameter, state, recipe)
#      37 """
#      38 Carry out the given recipe for the simulation by running
#      39 each task in the recipe.
#      40 """
#      41 for func in recipe:
# ---> 42     parameter, state = func(sim.algorithm, sim, parameter, state)
#      43 return parameter, state
#
# File ~/Research/qc_lab-dev/src/qc_lab/tasks/update_tasks.py:271, in update_quantum_classical_forces(algorithm, sim, parameters, state, **kwargs)
#     269 inds, mels, shape = state.dh_qc_dzc
#     270 # Calculate the expectation value w.r.t. the wavefunction.
# --> 271 state.quantum_classical_forces = functions.calc_sparse_inner_product(
#     272     inds, mels, shape, wf.conj(), wf
#     273 )
#     274 # Add the gauge field force if it exists and is requested.
#     275 gauge_field_force, has_gauge_field_force = sim.model.get("gauge_field_force")
#
# File ~/Research/qc_lab-dev/.venv/lib/python3.10/site-packages/numba/core/serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      26 # Keep unpickled object via `numba_unpickle` alive.
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)
#      42         unpickled object
#      43     """
#      44     key = (address, hashed)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Deterministic sampling
#
# To use deterministic sampling we multiply the number of trajectories and batch size by the number of states. Note that the convergence behavior changes.

# %%
sim = Simulation()

sim.settings.num_trajs = 20*7
sim.settings.batch_size = 5*7
sim.settings.tmax = 30
sim.settings.dt_update = 0.01

sim.model = FMOComplex({
    "kBT": 1,
    "mass": 1,
    "l_reorg": 35 / 208.521, # reorganization energy
    "w_c": 106.14 / 208.521, # characteristic frequency
    "N": 200,
})
sim.algorithm = FewestSwitchesSurfaceHopping({
    "fssh_deterministic":True,
    "gauge_fixing":'sign_overlap'
})

sim.state.wf_db= np.zeros(7, dtype=complex)
sim.state.wf_db[5] += 1.0

data = serial_driver(sim)

t = data.data_dict["t"]
plt.plot(t, np.real(np.einsum("tii->ti",data.data_dict["dm_db"])))
plt.title("Diabatic populations")
plt.show()
# Out:
# 100%|██████████| 3001/3001 [00:15<00:00, 192.13it/s]
# 100%|██████████| 3001/3001 [00:15<00:00, 191.47it/s]
# 100%|██████████| 3001/3001 [00:15<00:00, 192.38it/s]
# 100%|██████████| 3001/3001 [00:15<00:00, 189.48it/s]

# %% [markdown]
# ### Using a parllel driver
#
# w_ce will parallelize the above deterministic surface hopping calculation over four tasks.

# %%
from qc_lab.dynamics import parallel_driver_multiprocessing # import dynamics driver

sim = Simulation()

sim.settings.num_trajs = 20*7
sim.settings.batch_size = 5*7
sim.settings.tmax = 30
sim.settings.dt_update = 0.01

sim.model = FMOComplex({
    "kBT": 1,
    "mass": 1,
    "l_reorg": 35 / 208.521, # reorganization energy
    "w_c": 106.14 / 208.521, # characteristic frequency
    "N": 200,
})
sim.algorithm = FewestSwitchesSurfaceHopping({
    "fssh_deterministic":True,
    "gauge_fixing":'sign_overlap'
})

sim.state.wf_db= np.zeros(7, dtype=complex)
sim.state.wf_db[5] += 1.0

data = parallel_driver_multiprocessing(sim)

t = data.data_dict["t"]
plt.plot(t, np.real(np.einsum("tii->ti",data.data_dict["dm_db"])))
plt.title("Diabatic populations")
plt.show()
# Out:
# 100%|██████████| 3001/3001 [00:23<00:00, 129.09it/s]
# 100%|██████████| 3001/3001 [00:24<00:00, 124.43it/s]
# 100%|██████████| 3001/3001 [00:24<00:00, 123.78it/s]
# 100%|██████████| 3001/3001 [00:24<00:00, 122.07it/s]
