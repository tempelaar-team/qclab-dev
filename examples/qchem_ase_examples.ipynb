# %%
import numpy as np
import matplotlib.pyplot as plt
from qclab import Simulation, functions
from qclab.models import QChemASE
from qclab.algorithms import AbInitioFewestSwitchesSurfaceHopping
from qclab.dynamics import serial_driver
from ase.build import molecule
import ase.data.pubchem
from ase.visualize import view
from ase.io import write, read

# %%
mol = ase.data.pubchem.pubchem_atoms_search("cyclohexadiene")
view(mol, viewer='x3d')
write("chd.traj", mol)

# load
